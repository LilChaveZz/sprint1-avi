# %%
import pandas as pd

# Definir la ruta del archivo dentro de data/raw/
ruta_excel = 'data/raw/BDPIN_Marzo_2024.xlsx'

# Cargar únicamente la hoja "Data"
df = pd.read_excel(ruta_excel, sheet_name='Data')

# Mostrar las primeras 5 filas del DataFrame
df.head()
# Out:
#   STATION                DATE  HOUR  DIA  MES      O3  NO  NO2  NOX  SO2  ...  \
# 0     PIN 2024-03-01 00:00:00     0    1     3  0.011 NaN  NaN  NaN  NaN  ...
# 1     PIN 2024-03-01 01:00:00     1    1     3  0.011 NaN  NaN  NaN  NaN  ...
# 2     PIN 2024-03-01 02:00:00     2    1     3  0.021 NaN  NaN  NaN  NaN  ...
# 3     PIN 2024-03-01 03:00:00     3    1     3  0.010 NaN  NaN  NaN  NaN  ...
# 4     PIN 2024-03-01 04:00:00     4    1     3  0.005 NaN  NaN  NaN  NaN  ...
#
#    PM2.5     IT     ET  RH    WS    WD   PP  ATM  RS  UVI
# 0   52.6  20.97  15.06 NaN  5.24  51.0  0.0  NaN NaN  NaN
# 1   43.0  21.09  14.34 NaN   NaN  52.5  0.0  NaN NaN  NaN
# 2   24.5  21.00  13.58 NaN   NaN  54.0  0.0  NaN NaN  NaN
# 3   29.1  21.00  12.12 NaN   NaN  57.2  0.0  NaN NaN  NaN
# 4   56.1  21.29  11.00 NaN   NaN  59.5  0.0  NaN NaN  NaN
#
# [5 rows x 22 columns]
